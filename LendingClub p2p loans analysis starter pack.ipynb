# %%
# !pip install pathlib
# !pip install category_encoders

# %%
# Required packages
import pathlib

import category_encoders
import pandas as pd
import sklearn.impute
import sklearn.linear_model
import sklearn.metrics
import sklearn.pipeline
import sklearn.preprocessing
import yaml

# %% [markdown]
# ## Loading and Preprocessing Data

# %% [markdown]
# Refer to the [sample Jupyter notebook by Luke Merrick](https://gist.github.com/lukemerrick/af14f5b498ddf3900ba77c7bd840fc8c) to learn best ways to efficiently access the data.  The data has been provied in p2p_loans_470k_data/ in this repo.
#
# Luke Merrick has provided steps to load the data using the schema files provided in p2p_loans_470k_data/. This would ensure the data are loaded using the appropraite data type. He provides some guidance on preparing the data, and building an ML model with it.  His data preparation is very simple so you would need to do a more comprehensive data preparation to get hopefully better model prediction results

# %%
# define paths to all the files
data_dir = pathlib.Path('p2p_loans_470k_data/')

feature_schema_yaml = data_dir / 'feature_schema.yaml'
label_schema_yaml = data_dir / 'label_schema.yaml'

train_feature_csv = data_dir / 'train' / 'train_features.csv.gz'
train_label_csv = data_dir / 'train' / 'train_labels.csv.gz'
test_feature_csv = data_dir / 'test' / 'test_features.csv.gz'
test_label_csv = data_dir / 'test' / 'test_labels.csv.gz'

# %%
# load data into pandas dataset

with feature_schema_yaml.open() as yaml_file:
    feature_schema = yaml.load(yaml_file, Loader=yaml.FullLoader)
with label_schema_yaml.open() as yaml_file:
    label_schema = yaml.load(yaml_file, Loader=yaml.FullLoader)

# use them to intelligently import the data
train_features = pd.read_csv(train_feature_csv, **feature_schema)
train_labels = pd.read_csv(train_label_csv, **label_schema)
test_features = pd.read_csv(test_feature_csv, **feature_schema)
test_labels = pd.read_csv(test_label_csv, **label_schema)

# %%
train_labels.loan_status.unique()
# Out:
# ['Charged Off', 'Fully Paid']
# Categories (2, object): ['Charged Off', 'Fully Paid']

# %% [markdown]
# ## Data Dictionary

# %%
Refer to the following to understand what each feature stan

# %%
train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351088 entries, 36805548 to 36271262
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   loan_status              351088 non-null  category
#  1   issue_d                  351088 non-null  datetime64[ns]
#  2   zip_code_prefix          351088 non-null  object
#  3   grade                    351088 non-null  category
#  4   sub_grade                351088 non-null  category
#  5   installment              351088 non-null  float64
#  6   int_rate                 351088 non-null  float64
#  7   collection_recovery_fee  351088 non-null  float64
#  8   recoveries               351088 non-null  float64
#  9   debt_settlement_flag     351088 non-null  category
#  10  settlement_amount        4098 non-null    float64
#  11  settlement_date          4098 non-null    datetime64[ns]
#  12  settlement_percentage    4098 non-null    float64
#  13  settlement_status        4098 non-null    category
#  14  settlement_term          4098 non-null    float64
#  15  total_pymnt              351088 non-null  float64
#  16  total_pymnt_inv          351088 non-null  float64
#  17  total_rec_int            351088 non-null  float64
#  18  total_rec_late_fee       351088 non-null  float64
#  19  total_rec_prncp          351088 non-null  float64
# dtypes: category(5), datetime64[ns](2), float64(12), object(1)
# memory usage: 44.5+ MB

# %%
train_labels.head()
# Out:
#           loan_status    issue_d zip_code_prefix grade sub_grade  installment  \
# id
# 36805548  Charged Off 2014-12-01             937     A        A3       321.08
# 37662224  Charged Off 2014-12-01             850     C        C3       260.20
# 37822187   Fully Paid 2014-12-01             077     C        C3       326.53
# 37701596  Charged Off 2014-12-01             483     B        B5       332.10
# 37800722  Charged Off 2014-12-01             331     D        D5       468.17
#
#           int_rate  collection_recovery_fee  recoveries debt_settlement_flag  \
# id
# 36805548      6.99                  93.8286      521.27                    N
# 37662224     13.66                 222.8382     1237.99                    N
# 37822187     13.66                   0.0000        0.00                    N
# 37701596     11.99                   0.0000        0.00                    N
# 37800722     17.86                 272.7990     1515.55                    N
#
#           settlement_amount settlement_date  settlement_percentage  \
# id
# 36805548                NaN             NaT                    NaN
# 37662224                NaN             NaT                    NaN
# 37822187                NaN             NaT                    NaN
# 37701596                NaN             NaT                    NaN
# 37800722                NaN             NaT                    NaN
#
#          settlement_status  settlement_term  total_pymnt  total_pymnt_inv  \
# id
# 36805548               NaN              NaN      6611.69          6611.69
# 37662224               NaN              NaN      2281.98          2281.98
# 37822187               NaN              NaN      9973.43          9973.43
# 37701596               NaN              NaN      6957.45          6957.45
# 37800722               NaN              NaN      5746.89          5746.89
#
#           total_rec_int  total_rec_late_fee  total_rec_prncp
# id
# 36805548         872.67                 0.0          5217.75
# 37662224         339.61                 0.0           704.38
# 37822187         373.43                 0.0          9600.00
# 37701596        1562.16                 0.0          5395.29
# 37800722        1603.20                 0.0          2628.14

# %%
train_labels.describe()
# Out:
#          installment       int_rate  collection_recovery_fee     recoveries  \
# count  351088.000000  351088.000000            351088.000000  351088.000000
# mean      420.115238      12.629083                18.402367     123.076300
# std       256.784206       3.900596               100.572493     598.764747
# min        14.010000       5.930000                 0.000000       0.000000
# 25%       232.470000       9.670000                 0.000000       0.000000
# 50%       350.740000      12.490000                 0.000000       0.000000
# 75%       549.940000      15.100000                 0.000000       0.000000
# max      1409.990000      26.060000              6124.938000   34294.100000
#
#        settlement_amount  settlement_percentage  settlement_term  \
# count        4098.000000            4098.000000      4098.000000
# mean         2998.827230              46.968614         6.140068
# std          2491.401206              10.910215         7.741453
# min            44.210000              15.370000         0.000000
# 25%          1262.237500              44.352500         0.000000
# 50%          2342.715000              45.010000         1.000000
# 75%          3900.000000              50.000000        12.000000
# max         22896.570000             521.350000        36.000000
#
#          total_pymnt  total_pymnt_inv  total_rec_int  total_rec_late_fee  \
# count  351088.000000    351088.000000  351088.000000        3.510880e+05
# mean    13758.528821     13751.892402    2000.899161        9.619749e-01
# std      8978.211423      8974.182438    1630.008271        7.220580e+00
# min         0.000000         0.000000       0.000000       -1.800000e-09
# 25%      7102.820001      7099.920000     903.490000        0.000000e+00
# 50%     11634.704999     11624.600000    1588.505000        0.000000e+00
# 75%     18192.110265     18181.290000    2583.045000        0.000000e+00
# max     51067.368008     51067.370000   16602.700000        3.676000e+02
#
#        total_rec_prncp
# count    351088.000000
# mean      11633.591377
# std        7772.177487
# min           0.000000
# 25%        6000.000000
# 50%       10000.000000
# 75%       15300.000000
# max       35000.000000

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351088 entries, 36805548 to 36271262
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   loan_amnt                       351088 non-null  float64
#  1   emp_title                       327686 non-null  object
#  2   emp_length                      331440 non-null  category
#  3   home_ownership                  351088 non-null  category
#  4   annual_inc                      351088 non-null  float64
#  5   desc                            68438 non-null   object
#  6   purpose                         351088 non-null  category
#  7   title                           351083 non-null  object
#  8   addr_state                      351088 non-null  category
#  9   dti                             351088 non-null  float64
#  10  delinq_2yrs                     351088 non-null  float64
#  11  earliest_cr_line                351088 non-null  datetime64[ns]
#  12  inq_last_6mths                  351088 non-null  float64
#  13  mths_since_last_delinq          170214 non-null  float64
#  14  mths_since_last_record          54713 non-null   float64
#  15  open_acc                        351088 non-null  float64
#  16  pub_rec                         351088 non-null  float64
#  17  revol_bal                       351088 non-null  float64
#  18  revol_util                      350905 non-null  float64
#  19  total_acc                       351088 non-null  float64
#  20  collections_12_mths_ex_med      351088 non-null  float64
#  21  mths_since_last_major_derog     89459 non-null   float64
#  22  acc_now_delinq                  351088 non-null  float64
#  23  tot_coll_amt                    340478 non-null  float64
#  24  tot_cur_bal                     340478 non-null  float64
#  25  total_rev_hi_lim                340478 non-null  float64
#  26  acc_open_past_24mths            351088 non-null  float64
#  27  avg_cur_bal                     340469 non-null  float64
#  28  bc_open_to_buy                  347585 non-null  float64
#  29  bc_util                         347354 non-null  float64
#  30  chargeoff_within_12_mths        351088 non-null  float64
#  31  delinq_amnt                     351088 non-null  float64
#  32  mo_sin_old_rev_tl_op            340477 non-null  float64
#  33  mo_sin_rcnt_rev_tl_op           340477 non-null  float64
#  34  mo_sin_rcnt_tl                  340478 non-null  float64
#  35  mort_acc                        351088 non-null  float64
#  36  mths_since_recent_bc            347912 non-null  float64
#  37  mths_since_recent_inq           314563 non-null  float64
#  38  mths_since_recent_revol_delinq  120345 non-null  float64
#  39  num_accts_ever_120_pd           340478 non-null  float64
#  40  num_actv_bc_tl                  340478 non-null  float64
#  41  num_actv_rev_tl                 340478 non-null  float64
#  42  num_bc_sats                     350032 non-null  float64
#  43  num_bc_tl                       340478 non-null  float64
#  44  num_il_tl                       340478 non-null  float64
#  45  num_op_rev_tl                   340478 non-null  float64
#  46  num_rev_accts                   340478 non-null  float64
#  47  num_rev_tl_bal_gt_0             340478 non-null  float64
#  48  num_sats                        350032 non-null  float64
#  49  num_tl_120dpd_2m                332063 non-null  float64
#  50  num_tl_30dpd                    340478 non-null  float64
#  51  num_tl_90g_dpd_24m              340478 non-null  float64
#  52  num_tl_op_past_12m              340478 non-null  float64
#  53  pct_tl_nvr_dlq                  340364 non-null  float64
#  54  pub_rec_bankruptcies            351088 non-null  float64
#  55  tax_liens                       351088 non-null  float64
#  56  tot_hi_cred_lim                 340478 non-null  float64
#  57  total_bal_ex_mort               351088 non-null  float64
#  58  total_bc_limit                  351088 non-null  float64
#  59  total_il_high_credit_limit      340478 non-null  float64
#  60  fico_range_midpoint             351088 non-null  float64
# dtypes: category(4), datetime64[ns](1), float64(53), object(3)
# memory usage: 156.7+ MB

# %%
train_features.head()
# Out:
#           loan_amnt                       emp_title emp_length home_ownership  \
# id
# 36805548    10400.0  Truck Driver Delivery Personel    8 years       MORTGAGE
# 37662224     7650.0            Technical Specialist   < 1 year           RENT
# 37822187     9600.0                Admin Specialist  10+ years           RENT
# 37701596    10000.0           Investment Consultant    8 years           RENT
# 37800722    12975.0                           Sales  10+ years           RENT
#
#           annual_inc desc             purpose                    title  \
# id
# 36805548     58000.0  NaN         credit_card  Credit card refinancing
# 37662224     50000.0  NaN  debt_consolidation       Debt consolidation
# 37822187     69000.0  NaN  debt_consolidation       Debt consolidation
# 37701596     90000.0  NaN  debt_consolidation       Debt consolidation
# 37800722     60000.0  NaN               house              Home buying
#
#          addr_state    dti  ...  num_tl_90g_dpd_24m num_tl_op_past_12m  \
# id                          ...
# 36805548         CA  14.92  ...                 0.0                4.0
# 37662224         AZ  34.81  ...                 0.0                2.0
# 37822187         NJ  25.81  ...                 0.0                3.0
# 37701596         MI   8.44  ...                 0.0                0.0
# 37800722         FL  22.42  ...                 0.0                4.0
#
#           pct_tl_nvr_dlq  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id
# 36805548            83.3                   0.0        0.0         179407.0
# 37662224           100.0                   0.0        0.0          82331.0
# 37822187           100.0                   0.0        0.0          52490.0
# 37701596           100.0                   0.0        0.0          24200.0
# 37800722            89.5                   0.0        0.0          42943.0
#
#           total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# id
# 36805548            15030.0         13000.0                     11325.0
# 37662224            64426.0          4900.0                     64031.0
# 37822187            38566.0         21100.0                     24890.0
# 37701596            23723.0         21200.0                         0.0
# 37800722            17281.0          5500.0                     27243.0
#
#           fico_range_midpoint
# id
# 36805548                712.0
# 37662224                687.0
# 37822187                682.0
# 37701596                677.0
# 37800722                682.0
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Target feature

# %% [markdown]
# ### A regression model that predicts if a customer would default or not
# The ***loan_status*** feature in the ***train_label dataset*** is the <u>TARGET FEATURE </u>.  A loan is either assigned the  ***'Charged Off'*** label or  ***'Fully Paid'***.
#
# Loans labeled <strong><span style='color:red;'>'Charged Off'</span></strong> are loans LendingClub have deemed unlikely to be repaid because the borrower has been deliquent.
#
# Loans labeled <strong><span style='color:green;'>'Fully Paid'</span></strong> are loans that were fully paid.

# %%
train_labels.loan_status.unique()
# Out:
# ['Charged Off', 'Fully Paid']
# Categories (2, object): ['Charged Off', 'Fully Paid']

# %% [markdown]
# ### A customer risk categorization model using the FICO 5 levels rating (Poor, Fair, Good, Very Good, Exceptional)
# The ***fico_range_midpoint*** feature in the ***train_feature dataset*** is the <u>TARGET FEATURE </u>. Note this variable is currently numeric and would need to be converted into a five level categorical variable.
#
# Details on the FICO score can be found [here](https://www.myfico.com/credit-education/credit-scores).
#
# **NB:** when addressing the task you should also exclude the loan_status feature from the train

# %%
train_features.fico_range_midpoint.describe()
# Out:
# count    351088.000000
# mean        695.608336
# std          29.920541
# min         662.000000
# 25%         672.000000
# 50%         687.000000
# 75%         712.000000
# max         847.500000
# Name: fico_range_midpoint, dtype: float64

# %% [markdown]
# ### A customer risk categorization model using the FICO 5 levels rating (Poor, Fair, Good, Very Good, Exceptional)
#
# **Image Source:** [https://www.myfico.com/credit-education/credit-scores](https://www.myfico.com/credit-education/credit-scores)

# %% [markdown]
# ![title](assets/FICO_credit_score_grouping.PNG)

# %% [markdown]
# ## Resource materials and references

# %% [markdown]
# 1. [Sample Jupyter Notebook containing simple ML model](https://gist.github.com/lukemerrick/af14f5b498ddf3900ba77c7bd840fc8c)
# 2. [Detailed data dictionary for p2p loan data](https://www.kaggle.com/jonchan2003/lending-club-data-dictionary)
# 3. [Data dictionary in Excel format](https://resources.lendingclub.com/LCDataDictionary.xlsx)
# 4. [Data source](https://github.com/fiddler-labs/p2p-lending-data)
